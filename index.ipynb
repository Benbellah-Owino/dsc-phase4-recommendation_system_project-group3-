# %% [markdown]
# # **PHASE 4 MOVIE RECOMMENDATION PROJECT BY Group-3 Samuel Karu Hybrid**

# %% [markdown]
# ## **1. Business Understaning**<hr>

# %% [markdown]
# ### **1.1 Stakeholders**
# Our customer is LumeStream, a tech company dedicated to making movie watching more personal and fun. Its streaming service, also called LumeStream, blends popular films with carefully chosen indie titles, uses mood-based suggestions, and highlights community ratings and director spotlights, all in a simple, enjoyable app.

# %% [markdown]
# ### **1.2 Problem Statement**
#  An important component of the LumeStream service is the recommendation system, since it contributes to a great user experience. LumeStream has decided to outsource the recommendation engine to us.

# %% [markdown]
# ### **1.3 Project Objective**
# Build a model that provides top 5 movie recommendations to a user, based on their ratings of other movies.

# %% [markdown]
# ### **1.4 Model Objectives**
# * RMSE below 0.90
# * MAE below 0.70

# %% [markdown]
# ## **2. EDA**<hr>

# %% [markdown]
# ### **2.1 Imports and Data Loading**

# %%
#imports cell
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
mpl.rcParams.update({
    "xtick.color": "white",
    "ytick.color": "white",
    "axes.labelcolor": "white",
    "axes.edgecolor": "white"
})

# %%
links_df = pd.read_csv("./data/links.csv")
movies_df = pd.read_csv("./data/movies.csv")
ratings_df = pd.read_csv("./data/ratings.csv")
tags_df = pd.read_csv("./data/tags.csv")

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
tags_df
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %% [markdown]
# ### **2.2 Data exploration and cleaning**

# %% [markdown]
# #### 2.2.1 Movies dataset

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
# Descriptive analysis of the dataset (exclusive of id column)
movies_df.iloc[ :, 1:].describe()
# Out:
#               title genres
# count          9742   9742
# unique         9737    951
# top     Emma (1996)  Drama
# freq              2   1053

# %% [markdown]
# * We can see that drama is the genre combination with most entries.
# * We can see the modal title is Emma(1996) with a frequency of 2 meaning it's possibly a duplicate.
# * From the dataframes metadata we have 9742 entries but we only see 9737 unique values in the title column meaning 5 rows might be duplicates.

# %%
movies_df[movies_df["title"] == "Emma (1996)"]
# Out:
#       movieId        title                genres
# 650       838  Emma (1996)  Comedy|Drama|Romance
# 5601    26958  Emma (1996)               Romance

# %%
# Let's look at the columns with duplicates
movies_df[movies_df["title"].duplicated(keep=False)].sort_values("title")
# Out:
#       movieId                                   title  \
# 4169     6003  Confessions of a Dangerous Mind (2002)
# 9106   144606  Confessions of a Dangerous Mind (2002)
# 650       838                             Emma (1996)
# 5601    26958                             Emma (1996)
# 5854    32600                             Eros (2004)
# 9135   147002                             Eros (2004)
# 2141     2851                         Saturn 3 (1980)
# 9468   168358                         Saturn 3 (1980)
# 5931    34048                War of the Worlds (2005)
# 6932    64997                War of the Worlds (2005)
#
#                                    genres
# 4169          Comedy|Crime|Drama|Thriller
# 9106  Comedy|Crime|Drama|Romance|Thriller
# 650                  Comedy|Drama|Romance
# 5601                              Romance
# 5854                                Drama
# 9135                        Drama|Romance
# 2141            Adventure|Sci-Fi|Thriller
# 9468                      Sci-Fi|Thriller
# 5931     Action|Adventure|Sci-Fi|Thriller
# 6932                        Action|Sci-Fi

# %% [markdown]
# We can see a pattern in the duplicates here. The duplicates share a name with the originals and also the release year. From experience this is highly unlikely. We see while genres differ the duplicates contain atleast one genre from the original so we have to drop them.

# %% [markdown]
# We have specific rows we need to drop and also, the duplicates might have references in the other datasets which we will have to drop. For this table specifically we will put the duplicate(rows with the fewer genres) id's in an array and drop them one by one while in the reference tables we can use a join to ensure only entities with entries in both tables are present. We can even repeat the step given for the movies dataset.

# %%
movies_to_be_dropped_ids = [6003, 26958, 32600,	168358, 64997]

# %%
movies_df_no_dups = movies_df
for i in movies_to_be_dropped_ids:
    movies_df_no_dups = movies_df_no_dups[movies_df_no_dups["movieId"] != i]

movies_df = movies_df_no_dups
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9737 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9737 non-null   int64
#  1   title    9737 non-null   object
#  2   genres   9737 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 304.3+ KB

# %%
# Let's look at the columns with duplicates again
movies_df[movies_df["title"].duplicated(keep=False)].sort_values("title")
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres]
# Index: []

# %% [markdown]
# Great, we have dealt with the duplicates. However, the "genres" column has a problem. It is in the format of "Action|Adventure|Sci-Fi|", which is a pipe ('|') separated string meant to convey many genres in one string object. This is usable but it is more usable for analysis and modelling if it is separated out.<br>
# Doing this for both tasks is not going to be easy. But one easy way we can do this is create another genre and movie table that has a movieId and individual genre combo as the rows.

# %%
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9737 rows x 3 columns]

# %%
def separate_genres(row):
    genre_movies[row["movieId"]] = row["genres"].split("|")

genre_movies = {}
movies_df.copy().apply( separate_genres, axis=1)

genre_movies
# Out:
# {1: ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy'],
#  2: ['Adventure', 'Children', 'Fantasy'],
#  3: ['Comedy', 'Romance'],
#  4: ['Comedy', 'Drama', 'Romance'],
#  5: ['Comedy'],
#  6: ['Action', 'Crime', 'Thriller'],
#  7: ['Comedy', 'Romance'],
#  8: ['Adventure', 'Children'],
#  9: ['Action'],
#  10: ['Action', 'Adventure', 'Thriller'],
#  11: ['Comedy', 'Drama', 'Romance'],
#  12: ['Comedy', 'Horror'],
#  13: ['Adventure', 'Animation', 'Children'],
#  14: ['Drama'],
#  15: ['Action', 'Adventure', 'Romance'],
#  16: ['Crime', 'Drama'],
#  17: ['Drama', 'Romance'],
#  18: ['Comedy'],
#  19: ['Comedy'],
#  20: ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#  21: ['Comedy', 'Crime', 'Thriller'],
#  22: ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller'],
#  23: ['Action', 'Crime', 'Thriller'],
#  24: ['Drama', 'Sci-Fi'],
#  25: ['Drama', 'Romance'],
#  26: ['Drama'],
#  27: ['Children', 'Drama'],
#  28: ['Drama', 'Romance'],
#  29: ['Adventure', 'Drama', 'Fantasy', 'Mystery', 'Sci-Fi'],
#  30: ['Crime', 'Drama'],
#  31: ['Drama'],
#  32: ['Mystery', 'Sci-Fi', 'Thriller'],
#  34: ['Children', 'Drama'],
#  36: ['Crime', 'Drama'],
#  38: ['Children', 'Comedy'],
#  39: ['Comedy', 'Romance'],
#  40: ['Drama'],
#  41: ['Drama', 'War'],
#  42: ['Action', 'Crime', 'Drama'],
#  43: ['Drama'],
#  44: ['Action', 'Adventure', 'Fantasy'],
#  45: ['Comedy', 'Drama', 'Thriller'],
#  46: ['Drama', 'Romance'],
#  47: ['Mystery', 'Thriller'],
#  48: ['Animation', 'Children', 'Drama', 'Musical', 'Romance'],
#  49: ['Drama', 'Romance'],
#  50: ['Crime', 'Mystery', 'Thriller'],
#  52: ['Comedy', 'Drama', 'Romance'],
#  53: ['Adventure', 'Drama'],
#  54: ['Children', 'Comedy'],
#  55: ['Drama'],
#  57: ['Drama'],
#  58: ['Comedy', 'Drama', 'Romance'],
#  60: ['Adventure', 'Children', 'Fantasy'],
#  61: ['Drama', 'Thriller'],
#  62: ['Drama'],
#  63: ['Comedy', 'Crime'],
#  64: ['Comedy', 'Romance'],
#  65: ['Comedy'],
#  66: ['Action', 'Sci-Fi', 'Thriller'],
#  68: ['Comedy', 'Romance'],
#  69: ['Comedy'],
#  70: ['Action', 'Comedy', 'Horror', 'Thriller'],
#  71: ['Action'],
#  72: ['Comedy', 'Drama'],
#  73: ['Drama', 'War'],
#  74: ['Drama', 'Romance'],
#  75: ['Comedy', 'Drama'],
#  76: ['Action', 'Sci-Fi', 'Thriller'],
#  77: ['Documentary'],
#  78: ['Action', 'Crime', 'Drama', 'Thriller'],
#  79: ['Drama', 'Thriller'],
#  80: ['Children', 'Drama'],
#  81: ['Crime', 'Drama', 'Romance'],
#  82: ['Comedy', 'Drama'],
#  83: ['Drama', 'Romance'],
#  85: ['Drama', 'Romance'],
#  86: ['Action', 'Adventure', 'Drama'],
#  87: ['Children', 'Comedy'],
#  88: ['Comedy'],
#  89: ['Action', 'Thriller'],
#  92: ['Drama', 'Horror', 'Thriller'],
#  93: ['Comedy', 'Horror', 'Romance'],
#  94: ['Comedy', 'Drama', 'Romance'],
#  95: ['Action', 'Adventure', 'Thriller'],
#  96: ['Comedy', 'Drama'],
#  97: ['Crime', 'Drama'],
#  99: ['Documentary'],
#  100: ['Drama', 'Thriller'],
#  101: ['Adventure', 'Comedy', 'Crime', 'Romance'],
#  102: ['Comedy'],
#  103: ['Mystery', 'Sci-Fi', 'Thriller'],
#  104: ['Comedy'],
#  105: ['Drama', 'Romance'],
#  106: ['Comedy', 'Drama'],
#  107: ['Adventure', 'Children', 'Comedy', 'Musical'],
#  108: ['Documentary'],
#  110: ['Action', 'Drama', 'War'],
#  111: ['Crime', 'Drama', 'Thriller'],
#  112: ['Action', 'Adventure', 'Comedy', 'Crime'],
#  113: ['Drama', 'Mystery'],
#  116: ['Documentary'],
#  117: ['Crime', 'Drama'],
#  118: ['Comedy', 'Romance'],
#  119: ['Comedy'],
#  121: ['Drama'],
#  122: ['Comedy', 'Romance'],
#  123: ['Drama', 'Mystery', 'Romance'],
#  125: ['Comedy'],
#  126: ['Adventure', 'Children', 'Fantasy'],
#  128: ['Documentary'],
#  129: ['Comedy', 'Romance'],
#  132: ['Thriller'],
#  135: ['Comedy'],
#  137: ['Documentary'],
#  140: ['Drama', 'Romance'],
#  141: ['Comedy'],
#  144: ['Comedy'],
#  145: ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#  146: ['Adventure', 'Children'],
#  147: ['Drama'],
#  148: ['Drama'],
#  149: ['Crime', 'Drama', 'Thriller'],
#  150: ['Adventure', 'Drama', 'IMAX'],
#  151: ['Action', 'Drama', 'Romance', 'War'],
#  152: ['Drama', 'Horror'],
#  153: ['Action', 'Adventure', 'Comedy', 'Crime'],
#  154: ['Drama'],
#  155: ['Adventure', 'Drama', 'War'],
#  156: ['Comedy', 'Drama'],
#  157: ['Comedy', 'War'],
#  158: ['Adventure', 'Children'],
#  159: ['Crime', 'Drama', 'Mystery'],
#  160: ['Action', 'Adventure', 'Mystery', 'Sci-Fi'],
#  161: ['Drama', 'Thriller', 'War'],
#  162: ['Documentary'],
#  163: ['Action', 'Romance', 'Western'],
#  164: ['Crime', 'Film-Noir', 'Mystery', 'Thriller'],
#  165: ['Action', 'Crime', 'Thriller'],
#  166: ['Comedy', 'Crime', 'Drama'],
#  168: ['Action', 'Drama', 'Romance'],
#  169: ['Adventure', 'Children', 'Drama'],
#  170: ['Action', 'Adventure', 'Crime', 'Thriller'],
#  171: ['Comedy', 'Drama'],
#  172: ['Action', 'Sci-Fi', 'Thriller'],
#  173: ['Action', 'Crime', 'Sci-Fi'],
#  174: ['Comedy'],
#  175: ['Drama'],
#  176: ['Comedy'],
#  177: ['Horror'],
#  178: ['Comedy', 'Drama'],
#  179: ['Drama', 'Romance'],
#  180: ['Comedy', 'Romance'],
#  181: ['Action', 'Children'],
#  183: ['Comedy', 'Horror', 'Thriller'],
#  184: ['Drama'],
#  185: ['Action', 'Crime', 'Thriller'],
#  186: ['Comedy', 'Romance'],
#  187: ['Comedy'],
#  188: ['Fantasy', 'Horror', 'Mystery'],
#  189: ['Comedy', 'Fantasy'],
#  190: ['Thriller'],
#  191: ['Drama', 'Romance'],
#  193: ['Drama'],
#  194: ['Comedy', 'Drama'],
#  195: ['Comedy', 'Drama', 'Romance'],
#  196: ['Horror', 'Sci-Fi'],
#  198: ['Action', 'Crime', 'Drama', 'Mystery', 'Sci-Fi', 'Thriller'],
#  199: ['Drama', 'Musical', 'Romance'],
#  201: ['Drama', 'Fantasy'],
#  202: ['Drama', 'Romance'],
#  203: ['Comedy'],
#  204: ['Action'],
#  205: ['Comedy', 'Drama'],
#  206: ['Documentary'],
#  207: ['Drama', 'Romance'],
#  208: ['Action', 'Adventure', 'Sci-Fi'],
#  209: ['Drama'],
#  210: ['Western'],
#  211: ['Drama'],
#  212: ['Adventure', 'Comedy', 'Crime', 'Mystery'],
#  213: ['Drama'],
#  214: ['Drama', 'War'],
#  215: ['Drama', 'Romance'],
#  216: ['Comedy'],
#  217: ['Drama', 'Thriller'],
#  218: ['Comedy', 'Drama'],
#  219: ['Drama'],
#  220: ['Horror'],
#  222: ['Drama', 'Romance'],
#  223: ['Comedy'],
#  224: ['Comedy', 'Drama', 'Romance'],
#  225: ['Drama', 'Thriller'],
#  227: ['Action', 'Thriller'],
#  228: ['Comedy'],
#  229: ['Drama', 'Thriller'],
#  230: ['Drama', 'Thriller'],
#  231: ['Adventure', 'Comedy'],
#  232: ['Comedy', 'Drama', 'Romance'],
#  233: ['Drama'],
#  234: ['Comedy'],
#  235: ['Comedy', 'Drama'],
#  236: ['Action', 'Comedy', 'Romance'],
#  237: ['Comedy', 'Romance'],
#  238: ['Adventure', 'Children'],
#  239: ['Animation', 'Children', 'Comedy', 'Romance'],
#  240: ['Thriller'],
#  241: ['Children', 'Drama'],
#  242: ['Drama', 'Musical'],
#  243: ['Children', 'Comedy', 'Fantasy'],
#  246: ['Documentary'],
#  247: ['Crime', 'Drama'],
#  248: ['Comedy'],
#  249: ['Drama', 'Romance'],
#  250: ['Children', 'Comedy'],
#  251: ['Action'],
#  252: ['Comedy', 'Romance'],
#  253: ['Drama', 'Horror'],
#  254: ['Drama'],
#  255: ['Comedy'],
#  256: ['Comedy', 'Sci-Fi'],
#  257: ['Mystery', 'Thriller'],
#  258: ['Adventure', 'Children', 'Comedy', 'Fantasy', 'Romance'],
#  259: ['Crime', 'Drama', 'Thriller'],
#  260: ['Action', 'Adventure', 'Sci-Fi'],
#  261: ['Drama'],
#  262: ['Children', 'Drama'],
#  263: ['Drama'],
#  265: ['Drama', 'Fantasy', 'Romance'],
#  266: ['Drama', 'Romance', 'War', 'Western'],
#  267: ['Comedy'],
#  269: ['Drama'],
#  270: ['Drama', 'Romance'],
#  271: ['Drama'],
#  272: ['Comedy', 'Drama'],
#  273: ['Drama', 'Horror', 'Sci-Fi'],
#  274: ['Comedy'],
#  275: ['Comedy'],
#  276: ['Comedy', 'Romance'],
#  277: ['Drama'],
#  278: ['Comedy'],
#  279: ['Drama'],
#  280: ['Drama', 'Thriller'],
#  281: ['Comedy', 'Drama', 'Romance'],
#  282: ['Drama'],
#  283: ['Crime', 'Drama'],
#  284: ['Action', 'Crime'],
#  285: ['Drama', 'Horror'],
#  287: ['Comedy', 'Romance'],
#  288: ['Action', 'Crime', 'Thriller'],
#  289: ['Comedy', 'Romance'],
#  290: ['Crime', 'Drama'],
#  291: ['Drama', 'Thriller'],
#  292: ['Action', 'Drama', 'Sci-Fi', 'Thriller'],
#  293: ['Action', 'Crime', 'Drama', 'Thriller'],
#  294: ['Comedy', 'Romance'],
#  295: ['Comedy', 'Romance'],
#  296: ['Comedy', 'Crime', 'Drama', 'Thriller'],
#  298: ['Drama'],
#  299: ['Drama'],
#  300: ['Drama'],
#  301: ['Drama', 'Romance'],
#  302: ['Drama', 'Romance'],
#  303: ['Action', 'Thriller', 'Western'],
#  304: ['Comedy', 'Drama'],
#  305: ['Comedy'],
#  306: ['Drama'],
#  307: ['Drama'],
#  308: ['Comedy', 'Drama'],
#  310: ['Comedy'],
#  311: ['Horror', 'Thriller'],
#  312: ['Comedy'],
#  313: ['Animation', 'Children'],
#  314: ['Children', 'Drama', 'Fantasy', 'Mystery'],
#  315: ['Action', 'Drama', 'Thriller'],
#  316: ['Action', 'Adventure', 'Sci-Fi'],
#  317: ['Comedy', 'Drama', 'Fantasy'],
#  318: ['Crime', 'Drama'],
#  319: ['Comedy', 'Drama', 'Thriller'],
#  320: ['Film-Noir', 'Thriller'],
#  321: ['Drama'],
#  322: ['Comedy', 'Drama'],
#  324: ['Comedy', 'Drama'],
#  325: ['Comedy'],
#  326: ['Drama'],
#  327: ['Action', 'Comedy', 'Sci-Fi'],
#  328: ['Horror', 'Thriller'],
#  329: ['Adventure', 'Drama', 'Sci-Fi'],
#  330: ['Action', 'Crime', 'Horror'],
#  331: ['Drama'],
#  332: ['Horror', 'Sci-Fi'],
#  333: ['Comedy'],
#  334: ['Drama'],
#  335: ['Mystery', 'Thriller'],
#  336: ['Drama', 'War'],
#  337: ['Drama'],
#  338: ['Action', 'Sci-Fi', 'Thriller'],
#  339: ['Comedy', 'Romance'],
#  340: ['Adventure', 'Drama', 'War'],
#  341: ['Drama'],
#  342: ['Comedy'],
#  343: ['Children'],
#  344: ['Comedy'],
#  345: ['Comedy', 'Drama'],
#  346: ['Drama', 'Musical'],
#  347: ['Drama', 'Film-Noir', 'Romance'],
#  348: ['Comedy'],
#  349: ['Action', 'Crime', 'Drama', 'Thriller'],
#  350: ['Drama', 'Mystery', 'Thriller'],
#  351: ['Comedy', 'Drama', 'Romance'],
#  352: ['Comedy', 'Drama'],
#  353: ['Action', 'Crime', 'Fantasy', 'Thriller'],
#  354: ['Drama'],
#  355: ['Children', 'Comedy', 'Fantasy'],
#  356: ['Comedy', 'Drama', 'Romance', 'War'],
#  357: ['Comedy', 'Romance'],
#  358: ['Drama'],
#  359: ['Comedy', 'Drama', 'Romance'],
#  360: ['Action', 'Comedy'],
#  361: ['Comedy', 'Drama', 'Romance'],
#  362: ['Adventure', 'Children', 'Romance'],
#  363: ['Documentary'],
#  364: ['Adventure', 'Animation', 'Children', 'Drama', 'Musical', 'IMAX'],
#  365: ['Drama'],
#  366: ['Drama', 'Horror', 'Mystery', 'Thriller'],
#  367: ['Action', 'Comedy', 'Crime', 'Fantasy'],
#  368: ['Adventure', 'Comedy', 'Western'],
#  369: ['Drama'],
#  370: ['Action', 'Comedy'],
#  371: ['Comedy', 'Drama'],
#  372: ['Comedy', 'Drama', 'Romance'],
#  373: ['Thriller'],
#  374: ['Children', 'Comedy'],
#  376: ['Action', 'Thriller'],
#  377: ['Action', 'Romance', 'Thriller'],
#  378: ['Comedy', 'Romance'],
#  379: ['Action', 'Sci-Fi', 'Thriller'],
#  380: ['Action', 'Adventure', 'Comedy', 'Romance', 'Thriller'],
#  381: ['Drama', 'Romance'],
#  382: ['Drama', 'Horror', 'Romance', 'Thriller'],
#  383: ['Western'],
#  384: ['Action', 'Crime', 'Drama'],
#  385: ['Drama'],
#  386: ['Drama'],
#  387: ['Action', 'Comedy'],
#  388: ['Drama'],
#  389: ['Drama', 'Romance', 'War'],
#  390: ['Action', 'Crime', 'Drama'],
#  391: ['Crime', 'Drama'],
#  393: ['Action', 'Adventure', 'Fantasy'],
#  405: ['Action', 'Fantasy'],
#  406: ['Drama'],
#  407: ['Horror', 'Thriller'],
#  408: ['Drama'],
#  409: ['Crime', 'Drama'],
#  410: ['Children', 'Comedy', 'Fantasy'],
#  412: ['Drama'],
#  413: ['Comedy'],
#  414: ['Comedy'],
#  415: ['Comedy', 'Thriller'],
#  416: ['Western'],
#  417: ['Comedy', 'Romance'],
#  418: ['Drama'],
#  419: ['Comedy'],
#  420: ['Action', 'Comedy', 'Crime', 'Thriller'],
#  421: ['Adventure', 'Children', 'Drama'],
#  422: ['Thriller'],
#  423: ['Action', 'Thriller'],
#  424: ['Drama'],
#  425: ['Drama', 'Romance'],
#  426: ['Horror', 'Sci-Fi', 'Thriller'],
#  427: ['Drama', 'Mystery', 'Romance', 'Thriller'],
#  428: ['Drama'],
#  429: ['Comedy'],
#  430: ['Comedy', 'Drama'],
#  431: ['Crime', 'Drama'],
#  432: ['Adventure', 'Comedy', 'Western'],
#  433: ['Comedy'],
#  434: ['Action', 'Adventure', 'Thriller'],
#  435: ['Comedy', 'Sci-Fi'],
#  436: ['Drama', 'Thriller'],
#  437: ['Comedy'],
#  438: ['Action', 'Comedy', 'Drama'],
#  440: ['Comedy', 'Romance'],
#  441: ['Comedy'],
#  442: ['Action', 'Adventure', 'Sci-Fi'],
#  444: ['Comedy', 'Romance'],
#  445: ['Comedy'],
#  446: ['Drama', 'Romance'],
#  448: ['Drama'],
#  449: ['Comedy'],
#  450: ['Comedy', 'Drama'],
#  451: ['Drama', 'Mystery', 'Romance'],
#  452: ['Drama'],
#  453: ['Comedy', 'Romance'],
#  454: ['Drama', 'Thriller'],
#  455: ['Adventure', 'Children', 'Drama'],
#  456: ['Crime', 'Drama', 'Thriller'],
#  457: ['Thriller'],
#  458: ['Drama', 'Western'],
#  459: ['Action', 'Adventure', 'Crime', 'Drama', 'Romance', 'Thriller'],
#  460: ['Comedy'],
#  461: ['Drama', 'Romance'],
#  464: ['Action', 'Adventure', 'Crime', 'Thriller'],
#  466: ['Action', 'Comedy', 'War'],
#  467: ['Comedy'],
#  468: ['Comedy', 'Romance'],
#  469: ['Drama', 'Romance'],
#  470: ['Comedy'],
#  471: ['Comedy'],
#  472: ['Comedy', 'Drama'],
#  473: ['Comedy', 'War'],
#  474: ['Action', 'Thriller'],
#  475: ['Drama'],
#  476: ['Comedy', 'Drama'],
#  477: ['Drama', 'Musical'],
#  478: ['Comedy', 'Crime', 'Drama'],
#  479: ['Action', 'Crime', 'Thriller'],
#  480: ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  481: ['Drama', 'Thriller'],
#  482: ['Crime', 'Drama', 'Thriller'],
#  484: ['Adventure', 'Children'],
#  485: ['Action', 'Adventure', 'Comedy', 'Fantasy'],
#  486: ['Comedy'],
#  487: ['Comedy', 'Western'],
#  488: ['Drama', 'Romance'],
#  489: ['Comedy'],
#  490: ['Thriller'],
#  491: ['Drama'],
#  492: ['Comedy', 'Mystery'],
#  493: ['Action', 'Crime', 'Drama'],
#  494: ['Action', 'Adventure', 'Thriller'],
#  495: ['Drama'],
#  496: ['Comedy', 'Drama', 'Romance', 'Thriller'],
#  497: ['Comedy', 'Romance'],
#  499: ['Comedy', 'Romance'],
#  500: ['Comedy', 'Drama'],
#  501: ['Drama'],
#  502: ['Action', 'Children', 'Romance'],
#  504: ['Action', 'Drama', 'Sci-Fi'],
#  505: ['Comedy'],
#  506: ['Drama', 'Fantasy', 'Romance'],
#  507: ['Crime', 'Drama', 'Thriller'],
#  508: ['Drama'],
#  509: ['Drama', 'Romance'],
#  510: ['Drama'],
#  511: ['Action', 'Drama'],
#  512: ['Horror', 'Sci-Fi'],
#  513: ['Comedy', 'Mystery', 'Romance'],
#  514: ['Comedy'],
#  515: ['Drama', 'Romance'],
#  516: ['Comedy', 'Drama'],
#  517: ['Action', 'Drama', 'Mystery'],
#  518: ['Comedy'],
#  519: ['Action', 'Crime', 'Drama', 'Sci-Fi', 'Thriller'],
#  520: ['Comedy'],
#  521: ['Crime', 'Thriller'],
#  522: ['Action', 'Drama'],
#  523: ['Drama'],
#  524: ['Drama'],
#  526: ['Drama'],
#  527: ['Drama', 'War'],
#  528: ['Comedy', 'Drama'],
#  529: ['Drama'],
#  531: ['Children', 'Drama'],
#  532: ['Comedy', 'Crime', 'Horror'],
#  533: ['Action', 'Adventure', 'Fantasy', 'Mystery'],
#  534: ['Drama', 'Romance'],
#  535: ['Drama'],
#  536: ['Drama'],
#  537: ['Drama'],
#  538: ['Drama'],
#  539: ['Comedy', 'Drama', 'Romance'],
#  540: ['Thriller'],
#  541: ['Action', 'Sci-Fi', 'Thriller'],
#  542: ['Comedy', 'Drama', 'Romance'],
#  543: ['Comedy', 'Romance', 'Thriller'],
#  544: ['Action', 'Crime'],
#  546: ['Action', 'Adventure', 'Children', 'Comedy', 'Fantasy', 'Sci-Fi'],
#  547: ['Action', 'Adventure', 'Thriller'],
#  548: ['Action', 'Mystery', 'Thriller'],
#  549: ['Drama', 'Musical'],
#  550: ['Comedy', 'Romance'],
#  551: ['Animation', 'Children', 'Fantasy', 'Musical'],
#  552: ['Action', 'Adventure', 'Comedy', 'Romance'],
#  553: ['Action', 'Drama', 'Western'],
#  555: ['Crime', 'Thriller'],
#  556: ['Documentary'],
#  558: ['Action', 'Adventure', 'Animation', 'Children', 'Fantasy'],
#  562: ['Comedy', 'Drama'],
#  563: ['Drama', 'Romance'],
#  564: ['Comedy'],
#  567: ['Comedy', 'Drama'],
#  568: ['Comedy', 'Drama'],
#  569: ['Comedy', 'Drama'],
#  573: ['Drama'],
#  574: ['Comedy', 'Drama'],
#  575: ['Children', 'Comedy'],
#  577: ['Adventure', 'Children', 'Drama'],
#  579: ['Crime', 'Thriller'],
#  580: ['Drama'],
#  581: ['Documentary'],
#  583: ['Comedy', 'Drama'],
#  585: ['Comedy'],
#  586: ['Children', 'Comedy'],
#  587: ['Comedy', 'Drama', 'Fantasy', 'Romance', 'Thriller'],
#  588: ['Adventure', 'Animation', 'Children', 'Comedy', 'Musical'],
#  589: ['Action', 'Sci-Fi'],
#  590: ['Adventure', 'Drama', 'Western'],
#  592: ['Action', 'Crime', 'Thriller'],
#  593: ['Crime', 'Horror', 'Thriller'],
#  594: ['Animation', 'Children', 'Drama', 'Fantasy', 'Musical'],
#  595: ['Animation', 'Children', 'Fantasy', 'Musical', 'Romance', 'IMAX'],
#  596: ['Animation', 'Children', 'Fantasy', 'Musical'],
#  597: ['Comedy', 'Romance'],
#  599: ['Adventure', 'Western'],
#  600: ['Action', 'Comedy', 'Crime'],
#  602: ['Documentary'],
#  605: ['Drama', 'Romance'],
#  606: ['Fantasy', 'Horror'],
#  608: ['Comedy', 'Crime', 'Drama', 'Thriller'],
#  609: ['Adventure', 'Children'],
#  610: ['Action', 'Adventure', 'Animation', 'Horror', 'Sci-Fi'],
#  611: ['Action', 'Horror', 'Sci-Fi'],
#  612: ['Comedy'],
#  613: ['Drama', 'Romance'],
#  615: ['Comedy', 'Drama'],
#  616: ['Animation', 'Children'],
#  617: ['Comedy', 'Drama'],
#  618: ['Comedy', 'Romance'],
#  619: ['Comedy'],
#  626: ['Comedy'],
#  627: ['Drama', 'Thriller'],
#  628: ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  631: ['Adventure', 'Animation', 'Children', 'Fantasy', 'Musical', 'Romance'],
#  632: ['Drama', 'War'],
#  633: ['Comedy'],
#  634: ['Comedy'],
#  635: ['Comedy', 'Drama'],
#  636: ['Drama'],
#  637: ['Comedy'],
#  638: ['Romance'],
#  639: ['Comedy', 'Drama'],
#  640: ['Drama', 'Thriller'],
#  645: ['Drama'],
#  647: ['Action', 'Crime', 'Drama', 'War'],
#  648: ['Action', 'Adventure', 'Mystery', 'Thriller'],
#  649: ['Comedy', 'Drama'],
#  650: ['Drama'],
#  653: ['Action', 'Adventure', 'Fantasy'],
#  656: ['Comedy'],
#  661: ['Adventure', 'Animation', 'Children', 'Fantasy', 'Musical'],
#  662: ['Thriller'],
#  663: ['Comedy'],
#  665: ['Comedy', 'Drama', 'War'],
#  667: ['Action'],
#  668: ['Drama'],
#  670: ['Drama'],
#  671: ['Comedy', 'Sci-Fi'],
#  673: ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy', 'Sci-Fi'],
#  674: ['Adventure', 'Comedy', 'Sci-Fi'],
#  678: ['Drama', 'Thriller'],
#  679: ['Drama'],
#  680: ['Drama', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller'],
#  685: ['Drama'],
#  688: ['Action', 'Adventure', 'Comedy', 'War'],
#  691: ['Comedy', 'Romance'],
#  692: ['Action', 'Sci-Fi', 'Thriller'],
#  694: ['Action', 'Crime', 'Drama'],
#  695: ['Mystery', 'Thriller'],
#  697: ['Drama', 'Romance'],
#  698: ['Drama'],
#  700: ['Comedy'],
#  703: ['Drama'],
#  704: ['Action', 'Adventure'],
#  706: ['Drama'],
#  707: ['Crime', 'Drama', 'Thriller'],
#  708: ['Comedy', 'Romance'],
#  709: ['Adventure', 'Animation', 'Children', 'Comedy', 'Musical'],
#  710: ['Comedy'],
#  711: ['Adventure', 'Children'],
#  714: ['Drama', 'Mystery', 'Western'],
#  715: ['Drama', 'Romance'],
#  718: ['Comedy', 'Fantasy', 'Sci-Fi'],
#  719: ['Comedy'],
#  720: ['Adventure', 'Animation', 'Comedy'],
#  722: ['Documentary'],
#  724: ['Drama', 'Fantasy', 'Horror', 'Thriller'],
#  725: ['Comedy'],
#  726: ['Drama'],
#  728: ['Comedy'],
#  731: ['Crime', 'Thriller'],
#  733: ['Action', 'Adventure', 'Thriller'],
#  735: ['Horror'],
#  736: ['Action', 'Adventure', 'Romance', 'Thriller'],
#  737: ['Action', 'Sci-Fi'],
#  741: ['Animation', 'Sci-Fi'],
#  742: ['Horror', 'Thriller'],
#  743: ['Comedy'],
#  745: ['Animation', 'Children', 'Comedy'],
#  747: ['Comedy'],
#  748: ['Action', 'Sci-Fi', 'Thriller'],
#  750: ['Comedy', 'War'],
#  757: ['Drama'],
#  759: ['Documentary'],
#  760: ['Drama', 'War'],
#  761: ['Action', 'Adventure'],
#  762: ['Comedy', 'Crime'],
#  764: ['Drama', 'Romance'],
#  765: ['Comedy', 'Drama'],
#  766: ['Drama'],
#  773: ['Drama'],
#  775: ['Horror', 'Mystery'],
#  778: ['Comedy', 'Crime', 'Drama'],
#  779: ['Drama', 'Romance'],
#  780: ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  781: ['Drama'],
#  782: ['Drama', 'Thriller'],
#  783: ['Animation', 'Children', 'Drama', 'Musical', 'Romance'],
#  784: ['Comedy', 'Thriller'],
#  785: ['Comedy'],
#  786: ['Action', 'Drama', 'Thriller'],
#  788: ['Comedy', 'Fantasy', 'Romance', 'Sci-Fi'],
#  790: ['Drama'],
#  791: ['Documentary'],
#  795: ['Drama'],
#  798: ['Action', 'Adventure', 'Drama', 'Thriller'],
#  799: ['Comedy', 'Horror', 'Thriller'],
#  800: ['Drama', 'Mystery', 'Western'],
#  801: ['Children', 'Comedy'],
#  802: ['Drama', 'Romance'],
#  803: ['Comedy', 'Drama', 'Romance'],
#  804: ['Comedy', 'Romance'],
#  805: ['Drama', 'Thriller'],
#  806: ['Crime', 'Drama'],
#  808: ['Adventure', 'Children'],
#  809: ['Action', 'Adventure'],
#  810: ['Children', 'Comedy', 'Fantasy'],
#  813: ['Comedy'],
#  818: ['Comedy'],
#  823: ['Drama'],
#  824: ['Drama', 'Mystery'],
#  828: ['Adventure', 'Children'],
#  829: ['Comedy', 'Fantasy', 'Musical'],
#  830: ['Comedy'],
#  832: ['Crime', 'Thriller'],
#  833: ['Comedy'],
#  835: ['Drama'],
#  836: ['Action', 'Adventure', 'Thriller'],
#  837: ['Children', 'Comedy', 'Fantasy'],
#  838: ['Comedy', 'Drama', 'Romance'],
#  839: ['Action', 'Thriller'],
#  840: ['Children', 'Comedy'],
#  841: ['Horror'],
#  842: ['Comedy', 'Horror'],
#  848: ['Drama'],
#  849: ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  851: ['Drama'],
#  852: ['Comedy', 'Drama', 'Romance'],
#  858: ['Crime', 'Drama'],
#  861: ['Action', 'Comedy', 'Crime', 'Thriller'],
#  866: ['Crime', 'Drama', 'Romance', 'Thriller'],
#  867: ['Comedy', 'Crime'],
#  869: ['Crime', 'Drama', 'Musical', 'Thriller'],
#  870: ['Comedy'],
#  875: ['Action', 'Crime', 'Drama'],
#  876: ['Action', 'Comedy', 'Crime', 'Thriller'],
#  879: ['Horror', 'Thriller'],
#  880: ['Sci-Fi', 'Thriller'],
#  881: ['Children', 'Comedy'],
#  882: ['Drama', 'Thriller'],
#  885: ['Children', 'Drama', 'Fantasy'],
#  886: ['Action', 'Comedy', 'Crime'],
#  888: ['Adventure', 'Animation', 'Children', 'Musical'],
#  889: ['Drama', 'Romance'],
#  891: ['Horror', 'Thriller'],
#  892: ['Comedy', 'Drama', 'Romance'],
#  893: ['Drama'],
#  896: ['Drama'],
#  897: ['Adventure', 'Drama', 'Romance', 'War'],
#  898: ['Comedy', 'Drama', 'Romance'],
#  899: ['Comedy', 'Musical', 'Romance'],
#  900: ['Musical', 'Romance'],
#  901: ['Comedy', 'Musical'],
#  902: ['Drama', 'Romance'],
#  903: ['Drama', 'Mystery', 'Romance', 'Thriller'],
#  904: ['Mystery', 'Thriller'],
#  905: ['Comedy', 'Romance'],
#  906: ['Drama', 'Thriller'],
#  907: ['Comedy', 'Musical', 'Romance'],
#  908: ['Action', 'Adventure', 'Mystery', 'Romance', 'Thriller'],
#  909: ['Comedy', 'Drama', 'Romance'],
#  910: ['Comedy', 'Crime'],
#  911: ['Comedy', 'Crime', 'Mystery', 'Romance', 'Thriller'],
#  912: ['Drama', 'Romance'],
#  913: ['Film-Noir', 'Mystery'],
#  914: ['Comedy', 'Drama', 'Musical', 'Romance'],
#  915: ['Comedy', 'Romance'],
#  916: ['Comedy', 'Drama', 'Romance'],
#  917: ['Children', 'Drama'],
#  918: ['Musical'],
#  919: ['Adventure', 'Children', 'Fantasy', 'Musical'],
#  920: ['Drama', 'Romance', 'War'],
#  921: ['Comedy'],
#  922: ['Drama', 'Film-Noir', 'Romance'],
#  923: ['Drama', 'Mystery'],
#  924: ['Adventure', 'Drama', 'Sci-Fi'],
#  926: ['Drama'],
#  927: ['Comedy'],
#  928: ['Drama', 'Mystery', 'Romance', 'Thriller'],
#  929: ['Drama', 'Film-Noir', 'Mystery', 'Thriller'],
#  930: ['Film-Noir', 'Romance', 'Thriller'],
#  931: ['Mystery', 'Romance', 'Thriller'],
#  932: ['Drama', 'Romance'],
#  933: ['Crime', 'Mystery', 'Romance', 'Thriller'],
#  934: ['Comedy'],
#  935: ['Comedy', 'Musical'],
#  936: ['Comedy', 'Romance'],
#  937: ['Comedy', 'Romance'],
#  938: ['Musical'],
#  940: ['Action', 'Adventure', 'Romance'],
#  941: ['Adventure'],
#  942: ['Crime', 'Film-Noir', 'Mystery'],
#  943: ['Drama', 'Fantasy', 'Romance'],
#  944: ['Drama'],
#  945: ['Comedy', 'Musical', 'Romance'],
#  946: ['Comedy', 'Drama', 'War'],
#  947: ['Comedy', 'Romance'],
#  948: ['Drama', 'Romance', 'Western'],
#  949: ['Drama'],
#  950: ['Comedy', 'Crime'],
#  951: ['Comedy', 'Romance'],
#  952: ['Adventure', 'Comedy'],
#  953: ['Children', 'Drama', 'Fantasy', 'Romance'],
#  954: ['Drama'],
#  955: ['Comedy', 'Romance'],
#  956: ['Drama', 'Romance'],
#  959: ['Drama'],
#  961: ['Drama'],
#  963: ['Musical'],
#  965: ['Drama', 'Mystery', 'Thriller'],
#  968: ['Horror', 'Sci-Fi', 'Thriller'],
#  969: ['Adventure', 'Comedy', 'Romance', 'War'],
#  970: ['Adventure', 'Comedy', 'Crime', 'Drama', 'Romance'],
#  971: ['Drama'],
#  973: ['Comedy', 'Drama'],
#  976: ['Romance', 'War'],
#  979: ['Drama', 'War'],
#  981: ['Drama'],
#  982: ['Drama'],
#  984: ['Comedy', 'Drama'],
#  986: ['Adventure', 'Children'],
#  987: ['Drama', 'Romance'],
#  988: ['Comedy', 'Drama'],
#  990: ['Action', 'Adventure', 'Thriller'],
#  991: ['Drama'],
#  993: ['Drama'],
#  994: ['Comedy', 'Drama'],
#  996: ['Action', 'Crime', 'Drama', 'Thriller'],
#  998: ['Action', 'Crime'],
#  999: ['Crime', 'Film-Noir'],
#  1003: ['Drama', 'Thriller'],
#  1004: ['Action', 'Thriller'],
#  1005: ['Children', 'Comedy'],
#  1006: ['Drama'],
#  1007: ['Children', 'Comedy', 'Western'],
#  1008: ['Adventure', 'Western'],
#  1009: ['Adventure', 'Children', 'Fantasy'],
#  1010: ['Children', 'Comedy'],
#  1011: ['Children', 'Comedy', 'Fantasy', 'Romance'],
#  1012: ['Children', 'Drama'],
#  1013: ['Children', 'Comedy', 'Romance'],
#  1014: ['Children', 'Comedy', 'Drama'],
#  1015: ['Adventure', 'Children', 'Drama'],
#  1016: ['Children', 'Comedy'],
#  1017: ['Adventure', 'Children'],
#  1018: ['Children', 'Comedy', 'Mystery'],
#  1019: ['Adventure', 'Drama', 'Sci-Fi'],
#  1020: ['Comedy'],
#  1021: ['Children', 'Comedy'],
#  1022: ['Animation', 'Children', 'Fantasy', 'Musical', 'Romance'],
#  1023: ['Animation', 'Children', 'Musical'],
#  1024: ['Animation', 'Children', 'Musical'],
#  1025: ['Animation', 'Children', 'Fantasy', 'Musical'],
#  1027: ['Adventure', 'Drama'],
#  1028: ['Children', 'Comedy', 'Fantasy', 'Musical'],
#  1029: ['Animation', 'Children', 'Drama', 'Musical'],
#  1030: ['Adventure', 'Animation', 'Children', 'Musical'],
#  1031: ['Adventure', 'Children', 'Musical'],
#  1032: ['Adventure', 'Animation', 'Children', 'Fantasy', 'Musical'],
#  1033: ['Animation', 'Children', 'Drama'],
#  1034: ['Comedy', 'Crime', 'Drama', 'Thriller'],
#  1035: ['Musical', 'Romance'],
#  1036: ['Action', 'Crime', 'Thriller'],
#  1037: ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#  1040: ['Drama'],
#  1041: ['Drama'],
#  1042: ['Comedy', 'Drama'],
#  1043: ['Drama', 'Romance'],
#  1046: ['Drama', 'Romance'],
#  1047: ['Action', 'Drama', 'Thriller'],
#  1049: ['Action', 'Adventure'],
#  1050: ['Documentary', 'Drama'],
#  1051: ['Drama'],
#  1053: ['Crime', 'Drama', 'Romance'],
#  1054: ['Drama'],
#  1055: ['Thriller'],
#  1056: ['Drama'],
#  1057: ['Comedy', 'Musical', 'Romance'],
#  1059: ['Drama', 'Romance'],
#  1060: ['Comedy', 'Drama'],
#  1061: ['Thriller'],
#  1064: ['Animation', 'Children', 'Comedy', 'Fantasy', 'Musical', 'Romance'],
#  1066: ['Comedy', 'Musical', 'Romance'],
#  1068: ['Crime', 'Film-Noir'],
#  1073: ['Children', 'Comedy', 'Fantasy', 'Musical'],
#  1076: ['Drama', 'Horror', 'Thriller'],
#  1077: ['Comedy', 'Sci-Fi'],
#  1078: ['Comedy', 'War'],
#  1079: ['Comedy', 'Crime'],
#  1080: ['Comedy'],
#  1081: ['Comedy', 'Musical', 'Romance'],
#  1082: ['Drama'],
#  1083: ['Comedy', 'Musical'],
#  1084: ['Crime', 'Drama'],
#  1085: ['Adventure', 'Drama'],
#  1086: ['Crime', 'Mystery', 'Thriller'],
#  1088: ['Drama', 'Musical', 'Romance'],
#  1089: ['Crime', 'Mystery', 'Thriller'],
#  1090: ['Drama', 'War'],
#  1091: ['Comedy'],
#  1092: ['Crime', 'Mystery', 'Thriller'],
#  1093: ['Drama'],
#  1094: ['Drama', 'Romance', 'Thriller'],
#  1095: ['Drama'],
#  1096: ['Drama'],
#  1097: ['Children', 'Drama', 'Sci-Fi'],
#  1099: ['Children', 'Drama', 'Fantasy'],
#  1100: ['Action', 'Drama', 'Romance'],
#  1101: ['Action', 'Romance'],
#  1103: ['Drama'],
#  1104: ['Drama'],
#  1105: ['Horror'],
#  1107: ['Comedy'],
#  1111: ['Documentary'],
#  1112: ['Action', 'Comedy', 'Drama'],
#  1114: ['Crime', 'Drama'],
#  1116: ['Drama'],
#  1117: ['Drama'],
#  1119: ['Drama'],
#  1120: ['Comedy', 'Drama'],
#  1121: ['Drama'],
#  1123: ['Documentary'],
#  1124: ['Drama'],
#  1125: ['Comedy', 'Crime'],
#  1126: ['Comedy', 'Fantasy'],
#  1127: ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  1128: ['Horror'],
#  1129: ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#  1130: ['Horror', 'Mystery'],
#  1131: ['Drama', 'Mystery'],
#  1132: ['Drama'],
#  1135: ['Comedy'],
#  1136: ['Adventure', 'Comedy', 'Fantasy'],
#  1137: ['Romance'],
#  1140: ['Drama'],
#  1144: ['Documentary'],
#  1147: ['Documentary'],
#  1148: ['Animation', 'Children', 'Comedy', 'Crime'],
#  1150: ['Drama'],
#  1151: ['Animation', 'Comedy', 'Drama', 'Fantasy'],
#  1156: ['Drama'],
#  1161: ['Drama', 'War'],
#  1162: ['Comedy', 'Drama'],
#  1163: ['Drama'],
#  1167: ['Comedy'],
#  1170: ['Action'],
#  1171: ['Comedy'],
#  1172: ['Drama'],
#  1173: ['Comedy', 'Drama'],
#  1175: ['Comedy', 'Drama', 'Romance'],
#  1176: ['Drama', 'Fantasy', 'Romance'],
#  1177: ['Drama', 'Romance'],
#  1178: ['Drama', 'War'],
#  1179: ['Crime', 'Drama', 'Film-Noir'],
#  1180: ['Comedy'],
#  1183: ['Drama', 'Romance', 'War'],
#  1184: ['Comedy', 'Drama'],
#  1185: ['Drama'],
#  1186: ['Drama'],
#  1187: ['Drama'],
#  1188: ['Comedy', 'Romance'],
#  1189: ['Documentary'],
#  1190: ['Crime', 'Drama', 'Romance'],
#  1191: ['Documentary', 'Musical'],
#  1192: ['Documentary'],
#  1193: ['Drama'],
#  1194: ['Comedy'],
#  1196: ['Action', 'Adventure', 'Sci-Fi'],
#  1197: ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Romance'],
#  1198: ['Action', 'Adventure'],
#  1199: ['Fantasy', 'Sci-Fi'],
#  1200: ['Action', 'Adventure', 'Horror', 'Sci-Fi'],
#  1201: ['Action', 'Adventure', 'Western'],
#  1202: ['Comedy'],
#  1203: ['Drama'],
#  1204: ['Adventure', 'Drama', 'War'],
#  1206: ['Crime', 'Drama', 'Sci-Fi', 'Thriller'],
#  1207: ['Drama'],
#  1208: ['Action', 'Drama', 'War'],
#  1209: ['Action', 'Drama', 'Western'],
#  1210: ['Action', 'Adventure', 'Sci-Fi'],
#  1211: ['Drama', 'Fantasy', 'Romance'],
#  1212: ['Film-Noir', 'Mystery', 'Thriller'],
#  1213: ['Crime', 'Drama'],
#  1214: ['Horror', 'Sci-Fi'],
#  1215: ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Horror'],
#  1216: ['Adventure', 'Drama', 'Romance'],
#  1217: ['Drama', 'War'],
#  1218: ['Action', 'Crime', 'Drama', 'Thriller'],
#  1219: ['Crime', 'Horror'],
#  1220: ['Action', 'Comedy', 'Musical'],
#  1221: ['Crime', 'Drama'],
#  1222: ['Drama', 'War'],
#  1223: ['Adventure', 'Animation', 'Children', 'Comedy', 'Sci-Fi'],
#  1224: ['Action', 'Drama', 'Romance', 'War'],
#  1225: ['Drama'],
#  1226: ['Drama', 'Romance'],
#  1227: ['Crime', 'Drama'],
#  1228: ['Drama'],
#  1230: ['Comedy', 'Romance'],
#  1231: ['Drama'],
#  1232: ['Drama', 'Mystery', 'Sci-Fi'],
#  1233: ['Action', 'Drama', 'War'],
#  1234: ['Comedy', 'Crime'],
#  1235: ['Comedy', 'Drama', 'Romance'],
#  1236: ['Comedy', 'Drama', 'Romance'],
#  1237: ['Drama'],
#  1238: ['Comedy'],
#  1240: ['Action', 'Sci-Fi', 'Thriller'],
#  1241: ['Comedy', 'Fantasy', 'Horror'],
#  1242: ['Drama', 'War'],
#  1243: ['Comedy', 'Drama'],
#  1244: ['Comedy', 'Drama', 'Romance'],
#  1245: ['Crime', 'Drama', 'Film-Noir', 'Thriller'],
#  1246: ['Drama'],
#  1247: ['Comedy', 'Drama', 'Romance'],
#  1248: ['Crime', 'Film-Noir', 'Thriller'],
#  1249: ['Action', 'Crime', 'Romance', 'Thriller'],
#  1250: ['Adventure', 'Drama', 'War'],
#  1251: ['Drama', 'Fantasy'],
#  1252: ['Crime', 'Film-Noir', 'Mystery', 'Thriller'],
#  1253: ['Drama', 'Sci-Fi', 'Thriller'],
#  1254: ['Action', 'Adventure', 'Drama', 'Western'],
#  1255: ['Comedy', 'Horror', 'Sci-Fi'],
#  1256: ['Comedy', 'Musical', 'War'],
#  1257: ['Comedy', 'Romance'],
#  1258: ['Horror'],
#  1259: ['Adventure', 'Drama'],
#  1260: ['Crime', 'Film-Noir', 'Thriller'],
#  1261: ['Action', 'Comedy', 'Fantasy', 'Horror'],
#  1262: ['Action', 'Adventure', 'Drama', 'War'],
#  1263: ['Drama', 'War'],
#  1264: ['Action', 'Drama', 'Mystery', 'Romance', 'Thriller'],
#  1265: ['Comedy', 'Fantasy', 'Romance'],
#  1266: ['Drama', 'Western'],
#  1267: ['Crime', 'Thriller', 'War'],
#  1268: ['Comedy', 'Drama'],
#  1269: ['Comedy', 'Mystery', 'Thriller'],
#  1270: ['Adventure', 'Comedy', 'Sci-Fi'],
#  1271: ['Comedy', 'Crime', 'Drama'],
#  1272: ['Drama', 'War'],
#  1273: ['Comedy', 'Drama', 'Film-Noir'],
#  1274: ['Action', 'Adventure', 'Animation', 'Sci-Fi'],
#  1275: ['Action', 'Adventure', 'Fantasy'],
#  1276: ['Drama'],
#  1277: ['Comedy', 'Drama', 'Romance'],
#  1278: ['Comedy', 'Fantasy'],
#  1279: ['Comedy', 'Drama'],
#  1280: ['Drama'],
#  1281: ['Comedy', 'Drama', 'War'],
#  1282: ['Animation', 'Children', 'Fantasy', 'Musical'],
#  1283: ['Drama', 'Western'],
#  1284: ['Crime', 'Film-Noir', 'Mystery'],
#  1285: ['Comedy'],
#  1286: ['Drama', 'Romance'],
#  1287: ['Action', 'Adventure', 'Drama'],
#  1288: ['Comedy'],
#  1289: ['Documentary'],
#  1290: ['Drama', 'Romance'],
#  1291: ['Action', 'Adventure'],
#  1292: ['Comedy', 'Drama'],
#  1293: ['Drama'],
#  1295: ['Drama'],
#  1296: ['Drama', 'Romance'],
#  1297: ['Comedy'],
#  1298: ['Drama', 'Musical'],
#  1299: ['Drama', 'War'],
#  1300: ['Comedy', 'Drama'],
#  1301: ['Drama', 'Sci-Fi'],
#  ...}

# %%
# A function to visually inspect if what we've done is correct
def check_genre_movies(movieId):
    print(movies_df[movies_df["movieId"] == movieId]["genres"])
    print(genre_movies[movieId])

# A test function that tests all entries in movie_df and genre_movies match
def test_genre_movies():
    for i, row in movies_df.iterrows():
        val = genre_movies.get(row["movieId"]) #Get the genre_movies entry for this row
        exp = row["genres"].split("|") #Perform the spliting operation for the corresponding genres
        #exp.append("huh")  #uncomment this line to test if the assert works
        assert val == exp, f"Wrong paring for df -{exp}   dict{val}" #An assert to check if they are equal
    return True # Returns true to indicate the genre_movies dictionary has correct values from top to bottom

# %%
# 
check_genre_movies(100)
# Out:
# 88    Drama|Thriller
# Name: genres, dtype: object
# ['Drama', 'Thriller']

# %%
# When 
test_genre_movies()
# Out:
# True

# %%
#create the new dataframe
genre_movie_df = pd.DataFrame(columns=["movieId", "genre"])
genre_movie_df
# Out:
# Empty DataFrame
# Columns: [movieId, genre]
# Index: []

# %%
for i,genres in genre_movies.items():
    for g in genres:
        genre_movie_df = pd.concat([genre_movie_df, pd.DataFrame([{"movieId": i,"genre":g}])], ignore_index=True)

genre_movie_df
# Out:
#       movieId      genre
# 0           1  Adventure
# 1           1  Animation
# 2           1   Children
# 3           1     Comedy
# 4           1    Fantasy
# ...       ...        ...
# 22069  193583    Fantasy
# 22070  193585      Drama
# 22071  193587     Action
# 22072  193587  Animation
# 22073  193609     Comedy
#
# [22074 rows x 2 columns]

# %%
#Saved the dataframe to its own csv. We save in the generated folder to separate it from the main  project 
# data files. You can save it anywhere you like, this is our preference.

# Make sure you have created the generated folder inside the data folder if you use our save path
genre_movie_df.to_csv("./data/generated/genre_movie.csv", index=False)

# %% [markdown]
# * We now have a separate dataset containing movieId-genre pairing. This makes it so that one movie has only one genre so we can do more complex queries on the data.
# * Let's now do some simple analysis on the genres

# %%
genre_movie_df["genre"].value_counts()
# Out:
# Drama                 4359
# Comedy                3755
# Thriller              1892
# Action                1827
# Romance               1595
# Adventure             1263
# Crime                 1198
# Sci-Fi                 978
# Horror                 978
# Fantasy                779
# Children               664
# Animation              611
# Mystery                573
# Documentary            440
# War                    382
# Musical                334
# Western                167
# IMAX                   158
# Film-Noir               87
# (no genres listed)      34
# Name: genre, dtype: int64

# %%
# Deal with the no genres listed
genre_movie_df["genre"]=genre_movie_df["genre"].apply(lambda x: "Drama" if x=="(no genres listed)" else x)
genre_movie_df["genre"].value_counts()
# Out:
# Drama          4393
# Comedy         3755
# Thriller       1892
# Action         1827
# Romance        1595
# Adventure      1263
# Crime          1198
# Horror          978
# Sci-Fi          978
# Fantasy         779
# Children        664
# Animation       611
# Mystery         573
# Documentary     440
# War             382
# Musical         334
# Western         167
# IMAX            158
# Film-Noir        87
# Name: genre, dtype: int64

# %% [markdown]
# * Above we can see the count of all the genres.
# * Drama is the most common genre while film-noir is the least.
# * We have 34 movies with no genres
# <br>
# Below lets look at the genre combinations

# %%
movies_df["genres"].value_counts()
# Out:
# Drama                                                  1052
# Comedy                                                  946
# Comedy|Drama                                            435
# Comedy|Romance                                          363
# Drama|Romance                                           349
#                                                        ...
# Action|Crime|Horror|Mystery|Thriller                      1
# Adventure|Animation|Children|Comedy|Musical|Romance       1
# Action|Adventure|Animation|Comedy|Crime|Mystery           1
# Children|Comedy|Fantasy|Sci-Fi                            1
# Action|Animation|Comedy|Fantasy                           1
# Name: genres, Length: 951, dtype: int64

# %%
movies_df["genres"]=movies_df["genres"].apply(lambda x: "Drama" if x=="(no genres listed)" else x)
movies_df["genres"].value_counts()
# Out:
# Drama                                                  1086
# Comedy                                                  946
# Comedy|Drama                                            435
# Comedy|Romance                                          363
# Drama|Romance                                           349
#                                                        ...
# Action|Crime|Horror|Mystery|Thriller                      1
# Adventure|Animation|Children|Comedy|Musical|Romance       1
# Action|Adventure|Animation|Comedy|Crime|Mystery           1
# Children|Comedy|Fantasy|Sci-Fi                            1
# Action|Animation|Comedy|Fantasy                           1
# Name: genres, Length: 950, dtype: int64

# %% [markdown]
# While we have 951 different genres, drama and comedy still outrank all the combinations while the combination of the two also outranks the rest!

# %% [markdown]
# Let's extract the year from the title.

# %%
# extracting the year from the title column
movies_df['year'] = movies_df['title'].str.extract(r'\((\d{4})\)')
movies_df['year'] = movies_df['year'].astype("float")
movies_df['year'].head()
# Out:
# 0    1995.0
# 1    1995.0
# 2    1995.0
# 3    1995.0
# 4    1995.0
# Name: year, dtype: float64

# %%
# Plot the distibution
movies_df['year'].dropna().hist(bins=30, figsize=(10,5))
plt.title('movie release year distribution')
plt.xlabel('year')
plt.ylabel('number of movies')
plt.show()

# %% [markdown]
# #### 2.2.2 ratings df

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
ratings_df.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# * No null values in this dataset
# * Rating column is given a range from 0-5. However, our minimum rating is 0.5

# %%
# No duplicate rows in the dataset
ratings_df[ratings_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
# Let's look at the tags_df
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %% [markdown]
# No null values are present in the data.

# %%
# Dropping the timestamp columns in ratings and tags since we don't need them
ratings_df = ratings_df.drop(columns=["timestamp"])
tags_df = tags_df.drop(columns=["timestamp"])

# %%
tags_df.head()
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %% [markdown]
# links and tag tables are likely not usefull to us so we won't really bother with them.

# %% [markdown]
# ### **2.3 Further Analysis and Visualization**

# %% [markdown]
# We already looked at the genre table. Now lets plot our results

# %%
genre_counts = genre_movie_df["genre"].value_counts()
genre_counts
# Out:
# Drama          4393
# Comedy         3755
# Thriller       1892
# Action         1827
# Romance        1595
# Adventure      1263
# Crime          1198
# Horror          978
# Sci-Fi          978
# Fantasy         779
# Children        664
# Animation       611
# Mystery         573
# Documentary     440
# War             382
# Musical         334
# Western         167
# IMAX            158
# Film-Noir        87
# Name: genre, dtype: int64

# %%
type(genre_counts)
# Out:
# pandas.core.series.Series

# %%
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title(" A bar chat of the genres against their counts")
genre_counts.plot(kind="bar")
plt.show()

# %% [markdown]
# Below we explore the average rating of each movie

# %%
# Grouping the ratings by movie id so as to get the average rating for each movie
avg_ratings_per_movie = ratings_df.groupby("movieId")["rating"].mean()
avg_ratings_per_movie
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
type(avg_ratings_per_movie)
# Out:
# pandas.core.series.Series

# %%
plt.title(" A bhistogram of the ratings")
sns.histplot(x=avg_ratings_per_movie, bins=np.arange(0.5, 6.5, 1))
# Out:
# <AxesSubplot:title={'center':' A bhistogram of the ratings'}, xlabel='rating', ylabel='Count'>

# %% [markdown]
# Most movies are rated at the range of 2.5-4.5 and we can see it is a normal distribution.

# %%
# Below we do a left join of movies_df and avg_ratings_per_movie using the movieId table that is mutual to both. This ensures all rated movies get their rating
movie_rating = movies_df.join(avg_ratings_per_movie, on="movieId").sort_values("rating", ascending=False) 
movie_rating
# Out:
#       movieId                                  title                 genres  \
# 7656    88448  Paper Birds (Pájaros de papel) (2010)           Comedy|Drama
# 8107   100556             Act of Killing, The (2012)            Documentary
# 9083   143031                        Jump In! (2007)   Comedy|Drama|Romance
# 9094   143511                           Human (2015)            Documentary
# 9096   143559                    L.A. Slasher (2015)   Comedy|Crime|Fantasy
# ...       ...                                    ...                    ...
# 5749    30892     In the Realms of the Unreal (2004)  Animation|Documentary
# 5824    32160               Twentieth Century (1934)                 Comedy
# 5837    32371              Call Northside 777 (1948)  Crime|Drama|Film-Noir
# 5957    34482           Browning Version, The (1951)                  Drama
# 7565    85565                     Chalet Girl (2011)         Comedy|Romance
#
#         year  rating
# 7656  2010.0     5.0
# 8107  2012.0     5.0
# 9083  2007.0     5.0
# 9094  2015.0     5.0
# 9096  2015.0     5.0
# ...      ...     ...
# 5749  2004.0     NaN
# 5824  1934.0     NaN
# 5837  1948.0     NaN
# 5957  1951.0     NaN
# 7565  2011.0     NaN
#
# [9737 rows x 5 columns]

# %% [markdown]
# Let's look at the top rated movies

# %%
movie_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9737 entries, 7656 to 7565
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9737 non-null   int64
#  1   title    9737 non-null   object
#  2   genres   9737 non-null   object
#  3   year     9724 non-null   float64
#  4   rating   9719 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 456.4+ KB

# %%
movie_rating.describe()
# Out:
#              movieId         year       rating
# count    9737.000000  9724.000000  9719.000000
# mean    42191.324741  1994.612197     3.262470
# std     52156.096198    18.538691     0.870046
# min         1.000000  1902.000000     0.500000
# 25%      3247.000000  1988.000000     2.800000
# 50%      7297.000000  1999.000000     3.416667
# 75%     76251.000000  2008.000000     3.912872
# max    193609.000000  2018.000000     5.000000

# %%
# Let's deal with the rating by imputing with the mean
movie_rating["rating"] = movie_rating["rating"].fillna(movie_rating["rating"].mean())
movie_rating[movie_rating["rating"].isna()]
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres, year, rating]
# Index: []

# %%
movie_rating[movie_rating.duplicated()] # No duplicates available
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres, year, rating]
# Index: []

# %%
movie_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9737 entries, 7656 to 7565
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9737 non-null   int64
#  1   title    9737 non-null   object
#  2   genres   9737 non-null   object
#  3   year     9724 non-null   float64
#  4   rating   9737 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 456.4+ KB

# %%
# Let's save it to a csv file
movie_rating.to_csv("./data/generated/movie_rating.csv")

# %% [markdown]
# The dataset is now clean and ready to be worked omn

# %%
#TODO =  Lets plot a histogram of the movies and and the ratings 
perfect_movies = movie_rating[movie_rating["rating"] >= 5 ]
perfect_movies
# Out:
#       movieId                                          title  \
# 7656    88448          Paper Birds (Pájaros de papel) (2010)
# 8107   100556                     Act of Killing, The (2012)
# 9083   143031                                Jump In! (2007)
# 9094   143511                                   Human (2015)
# 9096   143559                            L.A. Slasher (2015)
# ...       ...                                            ...
# 5493    26350  Passenger, The (Professione: reporter) (1975)
# 3672     5059              Little Dieter Needs to Fly (1997)
# 5345     8911                        Raise Your Voice (2004)
# 4109     5889     Cruel Romance, A (Zhestokij Romans) (1984)
# 3807     5328                                    Rain (2001)
#
#                     genres    year  rating
# 7656          Comedy|Drama  2010.0     5.0
# 8107           Documentary  2012.0     5.0
# 9083  Comedy|Drama|Romance  2007.0     5.0
# 9094           Documentary  2015.0     5.0
# 9096  Comedy|Crime|Fantasy  2015.0     5.0
# ...                    ...     ...     ...
# 5493                 Drama  1975.0     5.0
# 3672           Documentary  1997.0     5.0
# 5345               Romance  2004.0     5.0
# 4109         Drama|Romance  1984.0     5.0
# 3807         Drama|Romance  2001.0     5.0
#
# [296 rows x 5 columns]

# %% [markdown]
#  Let's try to get the average rating per genre

# %%
genre_movie_df["movieId"]
# Out:
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#           ...
# 22069    193583
# 22070    193585
# 22071    193587
# 22072    193587
# 22073    193609
# Name: movieId, Length: 22074, dtype: object

# %%
genre_rating = genre_movie_df.join(movie_rating.set_index("movieId")[["rating"]], on="movieId")
genre_rating.head()
# Out:
#   movieId      genre   rating
# 0       1  Adventure  3.92093
# 1       1  Animation  3.92093
# 2       1   Children  3.92093
# 3       1     Comedy  3.92093
# 4       1    Fantasy  3.92093

# %%
genre_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22074 entries, 0 to 22073
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  22074 non-null  object
#  1   genre    22074 non-null  object
#  2   rating   22074 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 517.5+ KB

# %%
avg_ratings_per_genre = genre_rating.groupby("genre")["rating"].mean()
avg_ratings_per_genre
# Out:
# genre
# Action         3.094550
# Adventure      3.215267
# Animation      3.496735
# Children       3.107690
# Comedy         3.181669
# Crime          3.301496
# Documentary    3.779322
# Drama          3.420029
# Fantasy        3.218899
# Film-Noir      3.661092
# Horror         2.919316
# IMAX           3.311996
# Musical        3.296269
# Mystery        3.330364
# Romance        3.364465
# Sci-Fi         3.103359
# Thriller       3.156509
# War            3.570846
# Western        3.383389
# Name: rating, dtype: float64

# %%
type(avg_ratings_per_genre)
# Out:
# pandas.core.series.Series

# %%
# sns.barplot(avg_ratings_per_genre["genre"], avg_ratings_per_genre["rating"])
plt.figure(figsize=(10,8))
plt.xlabel("Genre")
plt.ylabel("Average rating")
avg_ratings_per_genre.sort_values(ascending=False).plot(kind="bar")
plt.show()

# %% [markdown]
# * We can see the genre ratings do not vary by much.
# * We can see documentary is the highest rated genre with 3.8
# * We can see documentary is the lowest rated genre with 2.9

# %%
# Adding userId for
genre_rating = genre_rating.join(ratings_df["userId"], on="movieId")
genre_rating
# Out:
#       movieId      genre   rating  userId
# 0           1  Adventure  3.92093     1.0
# 1           1  Animation  3.92093     1.0
# 2           1   Children  3.92093     1.0
# 3           1     Comedy  3.92093     1.0
# 4           1    Fantasy  3.92093     1.0
# ...       ...        ...      ...     ...
# 22069  193583    Fantasy  3.50000     NaN
# 22070  193585      Drama  3.50000     NaN
# 22071  193587     Action  3.50000     NaN
# 22072  193587  Animation  3.50000     NaN
# 22073  193609     Comedy  4.00000     NaN
#
# [22074 rows x 4 columns]

# %%
genre_rating.to_csv("./data/generated/genre_rating.csv")

# %% [markdown]
# ## **3. Modelling**<hr>

# %% [markdown]
# ### **3.1 Base Model**
# In this section, we will first create a Memory-based base model

# %%
#modelling imports
from surprise import Reader, Dataset
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD
from surprise.prediction_algorithms import KNNWithMeans, KNNBasic, KNNBaseline
from surprise.model_selection import GridSearchCV, train_test_split
from surprise.accuracy import rmse, mae

# %%
mv_rt_data = Dataset.load_from_df(ratings_df[["userId","movieId","rating"]], Reader())
trainset1, testset1 = train_test_split(mv_rt_data, test_size=0.3)
#dataset1 = mv_rt_data.build_full_trainset()

# %%
# Training the model
knn_base_model = KNNBasic()
knn_base_model.fit(trainset1)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
# A function for checking model perfomance
def model_perf_analyzer(model, test_data):
    preds = model.test(test_data)
    model_rmse = rmse(preds)
    model_mae = mae(preds)

# %%
model_perf_analyzer(knn_base_model, testset1)
# Out:
# RMSE: 0.9570
# MAE:  0.7339

# %% [markdown]
# We can see that on average our model's rating is almost 1 away from the true rating. Let's see If we can improve on that

# %% [markdown]
# ### **3.2 Now let's create a base SVD Model**

# %%
svd_model = SVD()
svd_model.fit(trainset1)

# %%
model_perf_analyzer(svd_model, testset1)
# Out:
# RMSE: 0.8808
# MAE:  0.6763

# %% [markdown]
# We have improced our model perfomance by quite a little bit.

# %%
print("n_factors:", svd_model.n_factors)
print("n_epochs:", svd_model.n_epochs)
print("learning rate:", svd_model.pu)
print("regularization:", svd_model.bu)
print("biased:", svd_model.biased)
# Out:
# n_factors: 100
# n_epochs: 20
# learning rate: [[-0.1465103   0.17961833  0.01744081 ...  0.07537205  0.02538528
#   -0.214069  ]
#  [-0.44872458  0.05600882  0.29444935 ... -0.3136064  -0.2521051
#   -0.35822979]
#  [-0.21627954  0.13100174 -0.04519671 ... -0.02828487 -0.12015364
#    0.02061772]
#  ...
#  [-0.08637334  0.01331326 -0.10837228 ...  0.01498883 -0.01142374
#    0.16185802]
#  [ 0.1949288  -0.15592315  0.06022394 ... -0.11618861 -0.20979319
#   -0.03196063]
#  [ 0.12010358 -0.0910138  -0.06962497 ...  0.06945136  0.17450275
#   -0.11715854]]
# regularization: [-1.47054487e-01 -2.58496500e-01  3.82688191e-01 -3.27958136e-01
#   1.20993015e-01 -9.69332151e-02 -2.03910549e-01  1.76875746e-02
#  -1.47856226e-01  1.14232923e-01 -3.73511008e-01 -2.27783604e-01
#  -2.79612247e-01 -8.58802697e-01 -4.28034645e-01 -5.19555430e-01
#  -1.22558550e-01 -1.81430657e-01  3.96827633e-01  4.85144371e-01
#  -3.24052293e-01  3.52921020e-01 -1.96439745e-03 -1.41655829e-01
#  -6.99916335e-01 -4.45689270e-01 -1.08738746e-01 -1.31712474e-01
#  -5.27357401e-01 -8.28436840e-01 -3.00375525e-01  8.55809792e-02
#   1.82471346e-02 -4.24758483e-01 -4.25876059e-01  2.65891781e-01
#  -6.51289663e-01 -1.03196553e-01 -1.59729549e-02 -3.43945892e-01
#  -2.33216065e-01 -4.62226796e-01  2.66388336e-01  3.26620611e-01
#  -1.32931560e+00  4.07740662e-01 -5.34563824e-01  1.24264710e-01
#   1.35407627e-02 -1.14361448e-01 -2.34976864e-01 -1.59770834e-01
#  -3.11196443e-01  2.71566907e-02 -6.64112722e-01  6.11805866e-01
#  -5.30409244e-01 -1.40435034e-01  2.93759907e-01 -4.48501635e-01
#  -5.51064575e-01 -8.77580575e-01  6.18534855e-02  1.59780733e-01
#  -1.21242900e-01 -9.57030732e-02  4.36830326e-01 -4.60924927e-01
#  -7.31510635e-01 -3.74452488e-01  2.91974228e-01 -8.38591043e-02
#   1.55341057e-01  2.64265418e-01 -6.49017578e-01  4.73372139e-01
#  -8.19003633e-01 -3.36170380e-01  4.47339488e-01  1.26383864e-01
#  -3.81890232e-01 -7.87861338e-01  6.80782204e-01 -6.58963290e-01
#   9.23122737e-02  3.08459291e-01 -4.79901058e-01  3.14809248e-01
#  -2.06938551e-01 -1.34001676e-01 -1.33739557e-01  1.08264951e-01
#  -5.26142302e-01  1.22244055e-01 -7.24917487e-01  7.31010043e-03
#  -5.53108647e-02 -7.47989749e-01 -7.64755283e-02  2.68761488e-02
#  -1.78666511e-02 -2.81015173e-01  3.77967390e-01  8.33522302e-02
#  -1.50832019e-01 -1.62635086e-01  2.24476285e-01 -2.74029804e-01
#   5.34450432e-02  2.43368313e-02 -1.20811923e+00  3.05742378e-01
#  -1.49390933e-01 -2.70296668e-01 -1.64319098e-01  5.07940769e-01
#   2.19912338e-01  1.88360470e-02 -3.49457219e-01 -2.25686971e-01
#  -5.14532222e-02  4.05468715e-01 -7.96495381e-01 -1.18283557e-01
#   3.09343834e-01  2.40852769e-01 -6.71102539e-02  8.85540213e-01
#  -3.51786438e-01  1.58241917e-01 -2.60302161e-01  2.52430904e-01
#   4.47104251e-01 -7.41410627e-01  5.10256130e-01  2.02291339e-01
#  -6.45370736e-01 -1.98509863e-03  1.21783438e-01  2.51870968e-01
#   2.52670053e-01 -2.86267197e-01 -2.45396832e-01 -5.51963891e-02
#   2.56532216e-01  4.46183531e-01  1.02292538e+00  2.27468675e-01
#  -9.81884258e-01  8.72960130e-02  4.88162529e-03  9.98689073e-02
#  -2.03074463e-01  5.75935853e-01  3.47508520e-01  4.07347863e-01
#  -3.74133397e-01  3.45478461e-01  1.45188673e-01 -8.25362239e-02
#  -3.42908583e-01  3.25285711e-01 -3.67014345e-02  2.52660930e-01
#   3.33623214e-01  1.91485215e-01  6.43611575e-01 -1.46098580e-01
#  -1.64236627e-01  1.18900317e-01  2.33866987e-01 -1.79027151e-01
#   1.38383653e-01 -2.60370259e-01  7.81620455e-01  7.14310467e-02
#   6.75033197e-01 -4.41128775e-01  1.87041334e-01  7.60920165e-01
#   3.25078028e-01 -3.95698576e-02 -6.71079616e-01 -1.06951832e-02
#  -4.68536662e-01 -5.48336702e-02  3.35016609e-01 -3.69007654e-01
#   4.30248795e-01 -2.05500291e-01  2.30211235e-01 -1.52423576e-01
#   4.03188707e-01  1.42817053e-01  4.70223415e-01 -8.61631765e-01
#   2.99092832e-01  3.67402838e-02  3.90425076e-01 -1.06900880e-01
#  -9.60327013e-02 -4.37093939e-02 -2.91303690e-01  4.07398266e-01
#   4.78838783e-01  7.87625686e-01 -1.19284123e+00  6.93541429e-01
#  -4.49544477e-01 -1.33571469e+00  2.38205231e-01 -4.16933181e-01
#  -4.26584818e-01  3.07701954e-01  1.56166417e-01  3.10990562e-01
#   7.12204181e-02 -1.53934736e-01  7.38125440e-01  1.39250980e-01
#  -1.37377092e-01  4.97696367e-01  4.81188564e-01 -2.47253115e-01
#  -1.10622388e-01  2.99858341e-01 -9.02632031e-01  1.96176708e-02
#  -1.92038891e-01 -7.28732097e-01  4.85243608e-01  3.81504990e-01
#  -4.04273801e-01  2.06978515e-01 -1.45993654e-03 -2.01542417e-01
#  -2.43723035e-01  8.08246990e-03  7.41245711e-02  4.24819548e-01
#   5.55976460e-02  5.01575438e-01 -1.89717291e-01  5.53675662e-02
#  -5.89884588e-01  5.45301680e-01 -2.67982134e-01 -1.06049591e-01
#   1.57913084e-01 -4.54993113e-01 -5.21029656e-01  6.76594041e-02
#  -1.10446751e-01 -3.14976105e-01  2.00549917e-01  8.26352566e-02
#   3.77159106e-01 -8.13401256e-01  3.57821623e-01 -1.91874500e-01
#   3.55679516e-01 -3.47539799e-01  3.98031058e-01  6.71668696e-01
#  -2.31524166e-01  2.70386606e-01 -9.53082798e-01  1.43263513e-01
#   3.91852325e-01 -1.79554730e-02  4.94896370e-01 -3.12516275e-01
#   9.33360917e-02 -4.44918041e-01  8.99094809e-02  3.13017169e-01
#   1.00707385e-01 -3.62844528e-01 -4.80737932e-02  3.30299797e-02
#  -9.93050838e-02  4.55003543e-02  6.17774579e-02 -1.25706752e-01
#  -4.89990622e-01  7.84447540e-02  7.88268592e-01 -8.52148114e-02
#   5.69234134e-01  4.36428316e-01 -6.83648408e-01  8.99887270e-02
#  -1.46201353e-01 -1.90032743e-02  5.34095862e-02  3.66982390e-01
#  -1.69503144e-01 -1.18578578e-01 -6.53629220e-01 -2.34398441e-01
#   7.36790831e-01 -1.74019741e-01  4.01982223e-01  3.79291179e-01
#   1.36077933e-01 -4.94904276e-01 -1.58381872e-01 -2.01935922e-01
#   4.19776415e-01  1.73406821e-01 -2.97879550e-01 -1.46009044e+00
#  -4.38749882e-01 -4.11103154e-01 -2.41395173e-01  2.44937209e-01
#  -6.10552303e-01  2.70859506e-01  6.74590393e-01  4.85274114e-01
#  -2.49549577e-01 -2.44339595e-01  5.12478835e-01  1.97922933e-01
#   2.08820697e-01  8.53206801e-02 -1.19251008e-01  2.86815691e-01
#  -8.14728606e-01 -1.81764112e-01  1.69668091e-01  1.27735758e-02
#   5.44688012e-01 -6.71254079e-02 -1.91513401e-01 -1.02864686e-01
#   1.27416272e-01 -1.94098161e-01  4.59194029e-01  1.67679760e-01
#  -2.72614135e-01  2.06785717e-02  1.67933477e-01 -6.78480279e-01
#   2.99571418e-01 -1.07889377e-01  4.75540096e-01 -2.06294584e-01
#  -9.45758221e-02 -1.44209866e+00 -1.26346164e-02 -3.01478569e-01
#  -5.22013793e-02 -2.47721249e-01  2.02185007e-01  2.03952350e-01
#  -1.19317097e-01 -1.04645406e+00  3.66506722e-01 -2.98347936e-01
#   3.55713990e-01  4.59683912e-01 -1.05304801e-01  3.84065915e-01
#  -1.68171088e-01  2.67382023e-01  7.25023821e-01 -2.11455739e-01
#   5.00403095e-01 -2.62482866e-01 -2.00309830e-01  3.59359475e-01
#   4.72118662e-01  3.94236907e-01 -1.05720154e-01  8.54788324e-02
#   2.75324126e-01 -4.08796828e-02  2.66973275e-01  1.16459646e-01
#   2.50955184e-01  8.68933669e-04  9.50978865e-02 -5.58827460e-02
#  -1.47162877e-02  1.39991946e-01 -1.97916037e-01  4.31211122e-02
#  -1.36788312e+00  1.85280782e-01 -3.48536390e-01  8.00967975e-02
#  -9.34815732e-03  4.82495064e-01  1.08050368e+00 -1.72164257e-02
#   3.77893469e-01  4.43556335e-01 -2.32623147e-01  1.40785448e-01
#   1.18745898e-02  1.07358470e-01 -5.56030431e-01  5.84946654e-02
#  -3.20121164e-01  7.02339820e-01 -6.04420099e-01  2.84248187e-01
#  -3.01526300e-01  3.51991841e-01  4.43709232e-01 -2.30413856e-01
#   6.89812803e-01 -7.10957821e-01 -3.77599624e-02 -2.38288693e-01
#   4.68931175e-01 -4.71172036e-01 -2.00294316e-01  8.78106015e-01
#   2.12269310e-01  2.98894993e-01  5.86452530e-01  2.31544091e-01
#  -3.40391348e-01 -2.15182066e-01  8.72829254e-02  3.76556685e-02
#   4.28696024e-01 -6.77976668e-02 -2.52831371e-01  3.24492941e-01
#  -6.02951452e-02  2.15091551e-01 -8.00039864e-02 -3.17518375e-01
#   2.27436628e-01 -7.34407668e-01 -4.82867225e-01  3.42915764e-02
#   3.56414182e-01 -5.81201583e-01  1.71830795e-01 -4.58979016e-01
#  -3.78843572e-01  5.37985356e-01  9.05955566e-02 -8.64278753e-02
#   4.97015299e-01 -2.79589928e-01 -4.31326737e-01 -3.01160831e-01
#   4.28579035e-01 -1.05800005e-01  1.34829887e-01  1.63122475e-02
#   2.58536341e-01  1.08877157e-01  4.71635367e-01  2.72514014e-01
#   2.52603518e-01  1.55556579e-01  1.01413345e-01 -1.41621841e-01
#  -8.88892875e-03 -4.28298245e-03 -6.20267679e-02  5.69483863e-01
#   3.86281456e-01 -3.45785674e-01 -2.86124773e-01  1.00082680e-02
#  -1.58846103e-01  2.07128006e-01 -1.37094905e-01 -1.73707427e-01
#  -2.24928004e-01  3.99943741e-01 -4.54030685e-01 -3.13247970e-01
#   4.92413654e-03 -3.43926666e-01  6.35129766e-03 -7.64192691e-01
#  -7.86190930e-02  4.28137645e-01  6.45106767e-01 -2.63445535e-01
#   3.44975040e-02  4.80159185e-01 -1.40244235e-01 -9.83694364e-02
#   2.28482017e-01 -1.21461512e-01  1.53733614e-01 -1.41352887e-01
#   6.94326946e-01  2.05937452e-01 -1.05603256e-01  3.42795887e-01
#   2.01995781e-01 -1.96842884e-01  7.07645091e-02  4.55023756e-01
#   5.76228623e-01  4.06669701e-01  1.87406633e-01  1.01187372e-01
#   5.94650780e-02  3.93400872e-02 -2.92314717e-02 -2.25233584e-01
#   2.37678717e-01  5.44526026e-01  1.89566789e-01 -2.78672988e-01
#   2.58966825e-01 -4.67154158e-01  2.98046773e-01 -1.40749033e-01
#  -8.17506525e-02  1.00604163e-01  8.08845736e-02  1.31493673e-01
#   4.77665591e-01  3.29303241e-01 -8.35555585e-01  1.24297610e-01
#   9.90636424e-02  2.72950295e-01 -4.25453027e-01  3.50898572e-01
#   7.61095835e-02 -4.02400016e-02  2.67395119e-01  5.01889554e-01
#  -4.33027795e-01  2.74572026e-01 -1.65407614e-01  2.07033268e-01
#  -8.10013501e-02 -2.09112025e-01 -2.37449326e-02  1.19089037e-01
#  -1.28910591e-01 -3.91349173e-02 -3.50805267e-01 -3.76583284e-02
#  -4.49986640e-01  6.73609308e-02  1.77869508e-02  6.18082827e-01
#   1.91623892e-01  4.75777997e-02 -3.31336227e-01  3.71248455e-01
#  -9.06416523e-01  3.89979272e-02  6.11991697e-01 -4.37711838e-02
#   2.22712660e-01  2.98251193e-01  4.12745338e-01 -5.17618880e-02
#   5.37213679e-02 -2.57516448e-01  6.80359986e-01 -1.76052352e-01
#   6.49423791e-01  2.30394927e-01 -4.92681203e-01  2.34325381e-01
#   2.99613473e-01 -5.55989419e-01  2.06846857e-01  2.20149561e-01
#  -2.28637983e-01  3.79901589e-01  6.19618878e-01  5.13750031e-01
#  -4.55975133e-01 -3.47904412e-01  5.78713469e-01  5.94981670e-02
#   5.14156904e-01 -1.33042924e-01  1.64827028e-02 -8.74348753e-03
#   1.07438028e-01 -1.78833080e-01 -1.54225046e+00  4.95439770e-01
#  -2.91079378e-01  1.74377871e-01  7.39135212e-01 -2.07477323e-01
#   6.91489043e-02  4.28032068e-01  1.01686046e-01 -5.31324113e-02
#  -6.01245444e-02 -2.85888005e-01  4.32912485e-01  7.40701057e-02
#   4.33295777e-01  3.03618995e-01 -2.37460213e-01  7.00469971e-02
#  -9.49649391e-01  6.33452683e-01]
# biased: True

# %% [markdown]
# ### **3.3 Hyperparameter tuning**

# %%
param_grid = {
    'n_factors': [2, 3, 4, 5, 10, 15, 20 , 25],
    'n_epochs': [  25,35, 37, 38, 39, 45],
    
    # Uncommenting this increases training time by a great deal
     'lr_pu': [0.002, 0.005, 0.01],
    'lr_qi': [0.002, 0.005, 0.01],

    # 'reg_pu': [0.02, 0.05, 0.1],
    # 'reg_qi': [0.02, 0.05, 0.1],

    # 'lr_bu': [0.002, 0.005],
    # 'lr_bi': [0.002, 0.005],
} 

gs_svd = GridSearchCV(SVD, param_grid, n_jobs=-1, joblib_verbose=5)
gs_svd.fit(mv_rt_data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed: 25.6min
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed: 44.1min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed: 58.5min
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed: 76.9min finished

# %%
gs_svd.best_params
# Out:
# {'rmse': {'n_factors': 2, 'n_epochs': 45, 'lr_pu': 0.01, 'lr_qi': 0.002},
#  'mae': {'n_factors': 3, 'n_epochs': 37, 'lr_pu': 0.01, 'lr_qi': 0.005}}

# %%
gs_svd.best_score
# Out:
# {'rmse': 0.8647700167427665, 'mae': 0.6626966783648994}

# %%
vssvd = SVD(n_factors=2, n_epochs=45, lr_pu=0.01, lr_qi=0.002)
vssvd.fit(trainset1)
model_perf_analyzer(vssvd, testset1)
# Out:
# RMSE: 0.8709
# MAE:  0.6668

# %% [markdown]
# ### **3.4 ADDITIONAL MODEL: SVD model but we use genres as our items**

# %%
gr_rt_data = Dataset.load_from_df(genre_rating[["userId","movieId","rating"]], Reader())
trainset2, testset2 = train_test_split(mv_rt_data, test_size=0.3)

# %%
genre_svd= SVD(n_factors=15, n_epochs=25)
genre_svd.fit(trainset2)

model_perf_analyzer(genre_svd, testset2)
# Out:
# RMSE: 0.8759
# MAE:  0.6731

# %% [markdown]
# ## **5. Evaluating**<hr>

# %%
from surprise.model_selection import cross_validate

algo = SVD()

cross_validate(
    algo,
    mv_rt_data,
    measures=['RMSE', 'MAE'],
    cv=5,
    verbose=True
)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8685  0.8765  0.8744  0.8695  0.8800  0.8738  0.0043
# MAE (testset)     0.6655  0.6721  0.6732  0.6682  0.6777  0.6713  0.0042
# Fit time          6.19    6.30    6.18    7.95    6.65    6.66    0.67
# Test time         0.18    0.29    0.24    0.30    0.41    0.28    0.08
# {'test_rmse': array([0.86852338, 0.87649527, 0.87436523, 0.86951544, 0.879979  ]),
#  'test_mae': array([0.66552207, 0.67207915, 0.67322687, 0.66816927, 0.67769638]),
#  'fit_time': (6.191075325012207,
#   6.300971746444702,
#   6.182743787765503,
#   7.954247951507568,
#   6.654139280319214),
#  'test_time': (0.17806649208068848,
#   0.29014086723327637,
#   0.24099302291870117,
#   0.29827427864074707,
#   0.4112396240234375)}

# %% [markdown]
# As you can see, when we cross-validate  the SVD algorithm, on average our tuned model is better in terms of the error rates. We can also see that the model is stable since the standard deviations are really low.

# %% [markdown]
# Our errror rates of RMSE - 0.8736 and an MAE -  0.6699 Indicate that the model is a good-strong model.

# %% [markdown]
# Saving our models to disk.

# %%
from surprise import dump

dump.dump("./models/movie_model.pkl", algo=vssvd)

# %%
dump.dump("./models/gene_model.pkl", algo=genre_svd)

# %% [markdown]
# Below we provide an api for getting n recommendations

# %%
def get_top_n_recommendations(model, trainset, user_inner_id, n=5):
    # Convert inner user id to raw id
    user_raw_id = trainset.to_raw_uid(user_inner_id)

    # Get items the user has already rated
    rated_items = set(j for (j, _) in trainset.ur[user_inner_id])

    preds = []

    for item_inner_id in trainset.all_items():
        if item_inner_id not in rated_items:
            item_raw_id = trainset.to_raw_iid(item_inner_id)
            pred = model.predict(user_raw_id, item_raw_id)
            preds.append((item_raw_id, pred.est))

    # Sort by predicted rating
    preds.sort(key=lambda x: x[1], reverse=True)

    return preds[:n]

# %%
def get_movie_details(movie_id, movies):
    return movies[movies["movieId"] == movie_id ]

# %%
top_5 = get_top_n_recommendations(vssvd, trainset1, user_inner_id=0)

for movie_id, score in top_5:
    print(f'\n--------------------------------------- {movie_id}')
    movie = get_movie_details(movie_id, movies_df)
    movie_title = movie["title"].iloc[0]
    print(f"Title : {movie_title}")
    print(f"Rating : {round(score, 2)}")
# Out:
# --------------------------------------- 898
# Title : Philadelphia Story, The (1940)
# Rating : 4.39
#
# --------------------------------------- 1104
# Title : Streetcar Named Desire, A (1951)
# Rating : 4.37
#
# --------------------------------------- 3030
# Title : Yojimbo (1961)
# Rating : 4.36
#
# --------------------------------------- 1208
# Title : Apocalypse Now (1979)
# Rating : 4.36
#
# --------------------------------------- 8874
# Title : Shaun of the Dead (2004)
# Rating : 4.35

# %% [markdown]
# ## **6. Solving the Cold start problem**<hr>

# %% [markdown]
# * During signing up, we ask the user to rate movies he has watched. We achieve this by providing a search function that compares their input to our movies.<br>
# * We can also rate our movies using the ratings of other streaming sites that share the same movies e.g. rate movies with Netflix and Prime ratings and create a pre-recommendation system then gather data as the users use our service.

# %% [markdown]
# ## **7. Recommendations**<hr>
# * The model is now ready to be integrated to the system since it fulfils our model objectives (RMSE - 0.87 & MAE - 0.67).
# * After collecting more user data, the company could build more complex but better perfoming models

# %% [markdown]
# ## **8. Conclusion**<hr>
# The recommendation system aims
# at improving customers
# experience by providing personalized movie suggestions.
#  The system was able to recommend
# relevant movies effectively.
